# %%
from load_data import *
import matplotlib.pyplot as plt
import numpy as np
from Models.Base import BaseNN
from Models.PCA import PCANN
from Models.AA import AANN
# Out:
# C:\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Using TensorFlow backend.

# %%
X_train, X_test, y_train, y_test = load_small_mnist(0.4)

# %% [markdown]
# Regular neural network

# %%
regular_nn = BaseNN([400, 200, 100, 60, 40, 30, 20, 15, 10]).fit(X_test, y_test, X_train, y_train, 200, 20)

# %% [markdown]
# PCA neural network

# %%
pca_nn = PCANN([400, 200, 100, 60, 40, 30, 20, 15, 10]).fit(X_test, y_test, X_train, y_train, 200, 20)

# %% [markdown]
# AA neural network

# %%
aa_nn = AANN([400, 200, 100, 60, 40, 30, 20, 15, 10], aa_iterations=5).fit(X_test, y_test, X_train, y_train, 200, 20)
# Out:
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=400)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=200)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(60, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=100)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(40, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=60)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(30, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=40)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(20, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=30)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(15, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=20)`
#   W_regularizer=l2(self.regularizer_factor)))
# C:\Users\Gasper\Desktop\mat-factorization-nnet\Models\AA.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="sigmoid", kernel_regularizer=<keras.reg..., input_dim=15)`
#   W_regularizer=l2(self.regularizer_factor)))

# %% [markdown]
# CA on test data

# %%
plt.plot(regular_nn[1], label = "random")
plt.plot(pca_nn[1], label = "pca")
plt.plot(aa_nn[1], label = "aa")
plt.legend(loc='lower right')
#plt.ylim([0.9, 1])
plt.show()

# %% [markdown]
# CA on train data

# %%
plt.plot(regular_nn[0], label = "random")
plt.plot(pca_nn[0], label = "pca")
plt.plot(aa_nn[0], label = "aa")
plt.legend(loc='lower right')
plt.ylim([0.99, 1])
plt.show()
